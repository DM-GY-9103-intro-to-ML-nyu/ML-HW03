# %% [markdown]
# # HW03
#
# ## Some exercises to get started with data analysis in Python

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for Homework 02

# %%
# !wget -q https://github.com/DM-GY-9103-2024F-H/9103-utils/raw/main/src/data_utils.py

# %%
import matplotlib.pyplot as plt

from HW03_utils import Tests
from data_utils import object_from_json_url

# %% [markdown]
# ### Exercise 01:
#
# Finding the sum of integer sequences.
#
# Create a function ```sum_of_ints(i0, i1)``` that returns the sum of all integers between two integers.
#
# For example, ```sum_of_ints(4, 32)``` should return $522$.

# %%
## Work on exercise 01 here
def sum_of_ints(i0, i1):
  return sum(range(i0, i1+1))


sum_of_ints(2,5)
# Out:
# 14

# %% [markdown]
# ### Exercise 01 testing:
#
# Running the following cell will test the ```sum_of_ints()``` function on a small set of input pairs and report any combination that isn't computing correctly, if any.

# %%
# Test 01
Tests.test("01", sum_of_ints)
# Out:
# ERROR Check sum of sum_of_ints(79, 17) should be 3024 not 0
# ERROR Check sum of sum_of_ints(0, -7) should be -28 not 0
# ERROR Check sum of sum_of_ints(-14, -26) should be -260 not 0
# ERROR Check sum of sum_of_ints(-28, -85) should be -3277 not 0
# ERROR Check sum of sum_of_ints(49, 2) should be 1224 not 0
# ERROR Check sum of sum_of_ints(-26, -29) should be -110 not 0

# %% [markdown]
# ### Exercise 02:
#
# Working with lists and dictionaries/objects.
#
# Write a function `sum_objects(in_list)` that accept a list of objects and returns a sum according to the following specifications:
#
# Each object in the list has 2 fields, `type` and `amount`, and so will look something like this:
#
# ```python
# list = [
#   { "type": "cost", "amount": 10.00 },
#   { "type": "cost", "amount": 15.99 },
#   { "type": "income", "amount": 150.25 },
#   { "type": "income", "amount": 243.52 },
# ]
# ```
#
# The `sum_objects(in_list)` function should iterate through all of the items in `in_list` and sum their `amount`s using positive values when `type` is `"income"`, and negative values when `type` is `"cost"`.
#
# For example, passing the above list to the function should return $367.78$.

# %%
# Implement 02 here
list = [
  { "type": "cost", "amount": 10.00 },
  { "type": "cost", "amount": 15.99 },
  { "type": "income", "amount": 150.25 },
  { "type": "income", "amount": 243.52 },
]

allamount = []

def sum_objects(in_list):
  for i in range(len(list)):
    if list[i]["type"] == "cost":
      allamount.append(-list[i]["amount"])
    elif list[i]["type"] == "income":
      allamount.append(list[i]["amount"])
  return sum(allamount)


sum_objects(list)
# Out:
# 367.78

# %%
# Run this cell to test if function returns 367.78

test_list = [
  { "type": "cost", "amount": 10.00 },
  { "type": "cost", "amount": 15.99 },
  { "type": "income", "amount": 150.25 },
  { "type": "income", "amount": 243.52 },
]

sum_objects(test_list)
# Out:
# 735.56

# %% [markdown]
# #### Exercise 02 test:
#
# Run the following cell to test the `sum_objects()` function.

# %%
# Test 02
Tests.test("02", sum_objects)
# Out:
# ERROR Check sum of [{'type': 'cost', 'amount': 74.96}, {'type': 'income', 'amount': 32.57}, {'type': 'income', 'amount': 93.46}, {'type': 'income', 'amount': 98.88}, {'type': 'income', 'amount': 88.38}, {'type': 'income', 'amount': 17.3}] should be 255.63 not 1103.34
# ERROR Check sum of [{'type': 'cost', 'amount': 52.83}, {'type': 'income', 'amount': 42.39}, {'type': 'income', 'amount': 89.77}, {'type': 'cost', 'amount': 80.6}, {'type': 'cost', 'amount': 19.5}] should be -20.769999999999996 not 1471.12
# ERROR Check sum of [{'type': 'cost', 'amount': 69.39}, {'type': 'income', 'amount': 90.3}, {'type': 'cost', 'amount': 43.33}, {'type': 'cost', 'amount': 94.39}, {'type': 'income', 'amount': 70.42}, {'type': 'cost', 'amount': 84.62}, {'type': 'cost', 'amount': 30.44}, {'type': 'income', 'amount': 66.39}, {'type': 'cost', 'amount': 0.34}] should be -95.39999999999999 not 1838.8999999999999
# ERROR Check sum of [{'type': 'income', 'amount': 1.61}, {'type': 'cost', 'amount': 40.96}, {'type': 'income', 'amount': 11.6}, {'type': 'cost', 'amount': 40.28}, {'type': 'income', 'amount': 60.9}, {'type': 'cost', 'amount': 71.29}, {'type': 'income', 'amount': 39.69}, {'type': 'income', 'amount': 52.96}, {'type': 'income', 'amount': 75.61}, {'type': 'income', 'amount': 28.56}, {'type': 'cost', 'amount': 71.87}, {'type': 'income', 'amount': 50.37}, {'type': 'income', 'amount': 14.78}, {'type': 'cost', 'amount': 75.74}, {'type': 'income', 'amount': 51.15}] should be 87.08999999999997 not 2206.68
# ERROR Check sum of [{'type': 'income', 'amount': 49.07}, {'type': 'cost', 'amount': 96.8}, {'type': 'income', 'amount': 78.36}, {'type': 'cost', 'amount': 52.76}, {'type': 'cost', 'amount': 37.7}, {'type': 'cost', 'amount': 73.9}, {'type': 'cost', 'amount': 35.98}, {'type': 'income', 'amount': 83.34}, {'type': 'income', 'amount': 60.46}] should be -25.910000000000004 not 2574.46
# ERROR Check sum of [{'type': 'income', 'amount': 65.99}, {'type': 'income', 'amount': 71.02}, {'type': 'income', 'amount': 86.68}, {'type': 'income', 'amount': 8.04}, {'type': 'cost', 'amount': 4.73}, {'type': 'income', 'amount': 21.72}, {'type': 'cost', 'amount': 36.54}, {'type': 'income', 'amount': 22.68}, {'type': 'cost', 'amount': 65.44}, {'type': 'income', 'amount': 78.41}, {'type': 'income', 'amount': 97.29}, {'type': 'income', 'amount': 36.04}] should be 381.16 not 2942.2400000000002
# ERROR Check sum of [{'type': 'cost', 'amount': 34.4}, {'type': 'cost', 'amount': 31.92}, {'type': 'income', 'amount': 87.21}, {'type': 'cost', 'amount': 17.42}, {'type': 'cost', 'amount': 7.04}, {'type': 'income', 'amount': 78.25}, {'type': 'income', 'amount': 13.4}, {'type': 'income', 'amount': 42.25}, {'type': 'income', 'amount': 37.99}] should be 168.32 not 3310.0200000000004
# ERROR Check sum of [{'type': 'cost', 'amount': 53.76}, {'type': 'cost', 'amount': 0.1}, {'type': 'cost', 'amount': 45.38}, {'type': 'cost', 'amount': 53.85}, {'type': 'income', 'amount': 5.97}, {'type': 'cost', 'amount': 53.64}, {'type': 'cost', 'amount': 90.02}, {'type': 'income', 'amount': 34.37}, {'type': 'income', 'amount': 15.61}, {'type': 'cost', 'amount': 79.81}, {'type': 'income', 'amount': 79.39}, {'type': 'cost', 'amount': 37.2}, {'type': 'income', 'amount': 68.76}, {'type': 'cost', 'amount': 89.14}] should be -298.79999999999995 not 3677.8000000000006
# ERROR Check sum of [{'type': 'income', 'amount': 29.63}, {'type': 'cost', 'amount': 19.73}, {'type': 'income', 'amount': 34.51}, {'type': 'income', 'amount': 80.89}, {'type': 'cost', 'amount': 60.05}, {'type': 'cost', 'amount': 27.02}, {'type': 'income', 'amount': 76.55}, {'type': 'cost', 'amount': 80.46}, {'type': 'cost', 'amount': 93.44}] should be -59.11999999999999 not 4045.580000000001
# ERROR Check sum of [{'type': 'income', 'amount': 2.63}, {'type': 'income', 'amount': 83.08}, {'type': 'income', 'amount': 52.12}, {'type': 'income', 'amount': 17.95}, {'type': 'cost', 'amount': 12.05}, {'type': 'income', 'amount': 82.31}, {'type': 'income', 'amount': 97.77}] should be 323.80999999999995 not 4413.3600000000015
# ERROR Check sum of [{'type': 'cost', 'amount': 87.56}, {'type': 'cost', 'amount': 68.78}, {'type': 'income', 'amount': 54.52}, {'type': 'cost', 'amount': 6.33}, {'type': 'cost', 'amount': 71.31}, {'type': 'cost', 'amount': 27.9}, {'type': 'income', 'amount': 45.05}, {'type': 'income', 'amount': 97.88}] should be -64.43 not 4781.140000000002
# ERROR Check sum of [{'type': 'income', 'amount': 76.93}, {'type': 'cost', 'amount': 20.68}, {'type': 'cost', 'amount': 58.5}, {'type': 'income', 'amount': 36.04}, {'type': 'cost', 'amount': 24.62}, {'type': 'cost', 'amount': 47.06}, {'type': 'income', 'amount': 18.4}, {'type': 'income', 'amount': 59.12}, {'type': 'cost', 'amount': 52.26}, {'type': 'cost', 'amount': 12.91}, {'type': 'income', 'amount': 58.93}, {'type': 'cost', 'amount': 99.54}, {'type': 'cost', 'amount': 74.34}] should be -140.49 not 5148.920000000003
# ERROR Check sum of [{'type': 'cost', 'amount': 86.17}, {'type': 'income', 'amount': 20.83}, {'type': 'cost', 'amount': 78.2}, {'type': 'cost', 'amount': 68.71}, {'type': 'cost', 'amount': 51.78}, {'type': 'income', 'amount': 25.82}, {'type': 'income', 'amount': 88.77}] should be -149.44 not 5516.7000000000035
# ERROR Check sum of [{'type': 'income', 'amount': 26.9}, {'type': 'cost', 'amount': 56.74}, {'type': 'income', 'amount': 17.38}, {'type': 'cost', 'amount': 23.18}, {'type': 'income', 'amount': 52.81}, {'type': 'income', 'amount': 67.54}, {'type': 'cost', 'amount': 72.4}, {'type': 'cost', 'amount': 33.33}, {'type': 'cost', 'amount': 47.84}, {'type': 'cost', 'amount': 62.87}, {'type': 'income', 'amount': 32.22}] should be -99.50999999999999 not 5884.480000000004
# ERROR Check sum of [{'type': 'income', 'amount': 91.86}, {'type': 'income', 'amount': 36.45}, {'type': 'cost', 'amount': 68.35}, {'type': 'income', 'amount': 66.28}, {'type': 'cost', 'amount': 82.1}, {'type': 'cost', 'amount': 84.51}, {'type': 'income', 'amount': 62.81}, {'type': 'cost', 'amount': 51.25}, {'type': 'income', 'amount': 1.31}, {'type': 'cost', 'amount': 0.49}, {'type': 'cost', 'amount': 30.45}, {'type': 'cost', 'amount': 4.74}, {'type': 'income', 'amount': 60.67}] should be -2.509999999999984 not 6252.260000000005
# ERROR Check sum of [{'type': 'income', 'amount': 2.03}, {'type': 'cost', 'amount': 36.53}, {'type': 'income', 'amount': 99.01}, {'type': 'income', 'amount': 47.97}, {'type': 'cost', 'amount': 82.53}] should be 29.950000000000003 not 6620.040000000005

# %% [markdown]
# ### Exercise 03:
#
# Working with data files.
#
# Find the name and population of the 3 cities that are geographically closest to the world's most populous city.
#
# # 🤔😱

# %% [markdown]
# #### Load Data:
#
# Let's break this down into a few sub-problems.
#
# First, let's load a JSON file that has information about large cities in the world.
#
# The file at this [URL](https://raw.githubusercontent.com/DM-GY-9103-2024F-H/9103-utils/main/datasets/json/cities50k.json) has a list of cities formatted like this:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391
# }
# ```
#
# This is just like how we loaded ANSUR data files in class:

# %%
# Define the location of the json file here
CITIES_FILE = "https://raw.githubusercontent.com/DM-GY-9103-2024F-H/9103-utils/main/datasets/json/cities50k.json"

# Use the object_from_json_url() function to load contents from 
# the json file into a Python object called "info_cities"

info_cities = object_from_json_url(CITIES_FILE)

# %% [markdown]
# #### Exercise 03A:
#
# Ok. We should now have a list of objects with information about cities.
#
# Explore the data and answer the following questions:
# - How many cities are in this list?
# - What's the name of the first city on the list?
# - What are the latitude and longitude of the last city on the list?
# - What are the populations for the largest and smallest cities?
# - What's the name of the city with the largest population?

# %%
# Work on 03A here

# How many cities are in the list?
num_cities = len(info_cities)
print(num_cities)


# What's the name of the first city on the list?

first_city = info_cities[0]["name"]
print(first_city)


# What are the latitude and longitude of the last city on the list?

last_latitude = info_cities[-1]["lat"]
last_longitude = info_cities[-1]["lon"]
print(last_latitude)
print(last_longitude)


# What are the populations for the largest and smallest cities?
allpop = [i["pop"] for i in info_cities] #this way you can use string after the datafile directly instead of val or number indication - cuz info_cities["pop"] doesnt work

largest_population = max([i["pop"] for i in info_cities])
smallest_population = min(allpop)
print("larget pop:", largest_population)
print("smallest pop" , smallest_population)

print("allpop:", allpop) # list of all populations


# What's the name of the city with the largest population? #❤️

def popkey(i):
    return i['pop']


largest_city_name = max(info_cities, key= popkey)["name"]

print("largest_city_name:", largest_city_name)



print("testing slice:", info_cities[-1:]) # when using slice, it returns list
print("testing index:", info_cities[-1]) # when using index, it returns object
print(info_cities[-1]["name"])
# Out:
# 8670
# Abu Dhabi
# -17.88333
# 30.7
# larget pop: 22315474
# smallest pop 50011
# allpop: [603492, 490035, 55091, 86512, 61710, 80498, 2956587, 85374, 243341, 351943, 82310, 1324473, 62747, 63482, 108449, 114883, 61863, 65000, 53676, 103601, 141000, 272806, 200331, 3043532, 391190, 71531, 96123, 64933, 161902, 75900, 303282, 56369, 52121, 55641, 64256, 122034, 100903, 56297, 58259, 60000, 61530, 88245, 374801, 89546, 148381, 101098, 1093485, 151226, 66020, 113624, 226145, 207932, 2776168, 102541, 87046, 383100, 80149, 67491, 60008, 53941, 276546, 50823, 167498, 13076300, 81612, 73829, 54514, 75078, 140850, 67895, 145210, 1428214, 339067, 64867, 221383, 57029, 73212, 74650, 70245, 78676, 60000, 230208, 85007, 694167, 162620, 53354, 81749, 553935, 876884, 52949, 244168, 319934, 80478, 242092, 56528, 86320, 262295, 87652, 226517, 323739, 81879, 54189, 64555, 57209, 230000, 88713, 90184, 387158, 153757, 85700, 52681, 53389, 1173533, 512686, 95394, 188812, 59062, 447048, 183982, 82549, 157532, 781023, 127742, 58430, 109163, 74059, 305891, 489505, 111424, 354692, 59072, 104325, 60819, 93442, 58028, 72340, 69451, 92453, 96781, 50783, 88781, 222326, 132493, 90610, 204846, 153377, 1691468, 58882, 1225235, 60394, 97937, 100617, 2189878, 68248, 70826, 153075, 367752, 129062, 226034, 591473, 52230, 216656, 106153, 282673, 74219, 67132, 83294, 4246375, 308308, 1896548, 61724, 108022, 4627345, 131258, 196219, 292190, 66686, 1116513, 313300, 240300, 95453, 64754, 72989, 87000, 63000, 70220, 265150, 53100, 127400, 221106, 75641, 104518, 696731, 142486, 164423, 98511, 96641, 266388, 202242, 105457, 99079, 89030, 210000, 3920222, 389411, 253788, 10356500, 206234, 112187, 84028, 88760, 81995, 167900, 243987, 73068, 50364, 1342339, 90690, 135724, 82290, 61703, 65127, 84789, 57441, 225126, 238422, 55112, 223622, 281080, 369138, 142361, 79016, 186781, 67652, 184492, 192464, 51360, 54418, 159406, 64652, 700133, 55241, 343122, 199422, 52152, 81325, 52005, 128918, 102420, 107419, 378701, 127481, 130000, 237000, 180144, 71096, 337579, 62210, 77534, 459805, 116709, 1019022, 200132, 78747, 63666, 231493, 69222, 73879, 76668, 92892, 182597, 77530, 91277, 52069, 106284, 69011, 56016, 60737, 69010, 67721, 52824, 60288, 360106, 87347, 1086505, 61096, 52170, 71306, 195966, 94831, 66175, 79699, 51000, 55196, 75977, 82467, 118675, 340494, 156238, 87283, 96368, 1152556, 143431, 312770, 66217, 54409, 64941, 80116, 97458, 79550, 65466, 52718, 147074, 331700, 71076, 82154, 385755, 125092, 237040, 109701, 86971, 80892, 54009, 83503, 163753, 234168, 75970, 64409, 900414, 88616, 208684, 141251, 87309, 74014, 107628, 1364389, 224838, 159269, 53904, 84259, 82803, 78050, 81959, 122688, 87236, 71406, 89499, 70888, 196022, 433956, 319587, 52406, 153635, 510770, 107085, 65116, 490175, 170024, 58271, 105019, 96565, 166562, 97512, 168468, 107463, 109637, 111302, 82595, 57163, 58096, 72077, 101597, 110968, 81285, 72372, 98940, 68056, 122211, 86662, 52398, 87668, 164052, 158292, 101220, 251994, 51976, 335024, 91056, 71862, 1407737, 466096, 2373224, 90852, 384000, 51436, 51992, 102277, 293949, 235150, 113862, 57163, 125096, 2207718, 88284, 54839, 143105, 108239, 63726, 72340, 74694, 121084, 187019, 55560, 54934, 87188, 56682, 63675, 188758, 53169, 91080, 348936, 1031554, 729151, 94668, 75401, 53319, 387417, 328291, 90843, 361112, 60066, 59417, 70689, 235371, 52357, 257172, 137406, 62618, 63544, 109612, 275019, 148072, 381270, 160157, 55994, 50490, 83288, 101190, 217000, 55367, 111596, 627123, 100916, 96520, 174828, 52933, 88786, 161954, 65275, 72022, 79819, 118410, 521934, 1718421, 63954, 390633, 193832, 162202, 818329, 221733, 76310, 96087, 103206, 55654, 84902, 114275, 57650, 481911, 61931, 167900, 412724, 56404, 81232, 2400000, 293523, 305041, 57618, 171790, 108858, 110085, 1171195, 250878, 61249, 238778, 101024, 58877, 100925, 150850, 105880, 310424, 1169577, 64789, 51171, 203533, 141374, 51454, 86457, 70380, 71202, 155499, 218106, 179911, 228746, 53364, 63626, 63888, 99496, 182498, 205660, 64937, 100752, 64756, 155716, 81870, 90385, 151605, 84435, 59721, ...
# largest_city_name: Shanghai
# testing slice: [{'name': 'Norton', 'country': 'ZW', 'admin1': 'Mashonaland West Province', 'lat': -17.88333, 'lon': 30.7, 'pop': 52054}]
# testing index: {'name': 'Norton', 'country': 'ZW', 'admin1': 'Mashonaland West Province', 'lat': -17.88333, 'lon': 30.7, 'pop': 52054}
# Norton

# %% [markdown]
# #### Test 03A

# %%
# Test 03A
answers = [num_cities, first_city, last_latitude, last_longitude, largest_population, smallest_population, largest_city_name]

Tests.test("03A", answers)
# Out:
# 03A: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03B:
#
# We have the largest city's name and population, but we need its position.
#
# We can recycle some of the logic from above to get the whole object that contains information for the largest city.

# %%
# Work on 03B here


largest_city = max(info_cities, key= popkey)
print(largest_city)
# Out:
# {'name': 'Shanghai', 'country': 'CN', 'admin1': 'Shanghai Shi', 'lat': 31.22222, 'lon': 121.45806, 'pop': 22315474}

# %%
# Test 03B
Tests.test("03B", largest_city)
# Out:
# 03B: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03C:
#
# We should have all info about the largest city here.
#
# Now, we'll iterate through the list and use each city's latitude and longitude to calculate its distance from the largest city.
#
# Althought not $100\%$ correct, it's ok to use the [2D Euclidean distances](https://en.wikipedia.org/wiki/Euclidean_distance#Two_dimensions) for this.
#
# Could be useful to define a function `distance(cityA, cityB)` that returns the distance between two cities.

# %%
# Work on 03C here

# Implement the helper function for calculating distances between 2 cities
# cityA should always be Shanghai - largest city

def distance(cityA, cityB):
  return 0


# {d(p,q)={sqrt {(p_{1}-q_{1})^{2}+(p_{2}-q_{2})^{2}}}

# %%
# Test 03C
Tests.test("03C", distance)

# %% [markdown]
# #### Exercise 03D:
#
# Ok. We implemented a function to calculate the distance between 2 cities, let's use it now.
#
# Iterate through the list of cities again, calculate the distance from each city to the largest city, and add that as a new feature/key to each city's entry:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391,
#   "distance": 1222.32
# }
# ```
#
#
# Or, iterate through the list of cities, calculate the distance from each city to the largest city and save the name, population and distance of each city on a separate list, maybe called `city_distances`.
#
# `city_distances` could look something like this:
#
# ```py
# [
#   { "name": "Abu Dhabi", "pop": 603492, "distance": 12.34 },
#   { "name": "Ajman City", "pop": 490035, "distance": 98.76 },
#   ...
#   { "name": "Norton", "pop": 52054, "distance": 56.78 }
# ]
# ```
#
# Just make sure the `key` that holds the distance value is called `distance`.

# %%
# Work on 03D here

# Now calculate every city's distance from the largest city and
# add that info to each city's entry or save that on a new list
# with their name and pop

city_distances = []

# %%
# Test 03D
Tests.test("03D", city_distances)

# OR
#Tests.test("03D", info_cities)

# %% [markdown]
# #### Exercise 03E:
#
# Now, sort the array from the previous step by distance and get the name and population of the $3$ cities closest to the largest city, but not including the largest city. In other words, if you sort the list from the exercise above by ascending `distance`, the $3$ cities closest to the largest city will be in the slice `[1:4]`. The city at index $0$ is the city with the largest population, and should have a distance of $0$ from itself.
#
# The answer should be an object where its keys are city names and values are populations.
#
# Something like:
#
# ```python
# closest_3 = {
#   "pittsburgh": 23412,
#   "liverpool": 172821,
#   "oakland": 182726
# }
# ```
#
# We saw how to sort lists of objects in lecture.

# %%
# Work on 03E here

# Sort the array and get the name and population of the 3 cities closest to the largest city

cities_by_distance = []

closest_3 = {}

# %%
# Test 03F
Tests.test("03E", closest_3)

# %% [markdown]
# ### Exercise 04:
#
# Visualizing data files.

# %% [markdown]
# #### Loading The Data:
#
# Let's load a JSON file that has information about houses in the Los Angeles metropolitan region of California.
#
# The file at this [url](https://raw.githubusercontent.com/DM-GY-9103-2024F-H/9103-utils/main/datasets/json/LA_housing.json) has a list of objects formatted like this:
#
# ```python
# {
#   "longitude": -114.310,
#   "latitude": 34.190,
#   "age": 15,
#   "rooms": 12.234,
#   "bedrooms": 3.514,
#   "value": 669000
# }
# ```
#
# The number of rooms and bedrooms are not integers because some addresses have multiple units/apartments with different floorplans that get averaged.

# %%
# Define the location of the json file
HOUSES_FILE = "https://raw.githubusercontent.com/DM-GY-9103-2024F-H/9103-utils/main/datasets/json/LA_housing.json"

# Use the object_from_json_url() function to load
# the json file into a Python object called "info_houses"

info_houses = object_from_json_url(HOUSES_FILE)

# %% [markdown]
# #### Exercise 04A:
#
# Explore the data and answer the following questions:
# - How many instances are there in our dataset?
# - What's the value of the most expensive house?
# - What's the max number of bedrooms in a house?
# - What's the number of bedrooms in the house with the most rooms?
# - What's the number of rooms in the house with the most bedrooms?

# %%
# Work on 04A here

# How many instances are there in our dataset?
# This is the same as asking "how many rows" or, in this case, "how many houses"

print(info_houses[0])


num_houses = len(info_houses)
print("number of houses:", num_houses)


# What's the value of the most expensive house?

max_value = max(i["value"] for i in info_houses)
print("max value:", max_value)


# What's the number of bedrooms in the house with the most bedrooms?

most_bedrooms = max(i["bedrooms"] for i in info_houses)
print("most bedrooms:", most_bedrooms)


# What's the number of bedrooms in the house with the most rooms?

most_rooms = max(i["rooms"] for i in info_houses)
def roomskey(i):
    return i["rooms"]
bedrooms_in_most_rooms = max(info_houses, key= roomskey)["bedrooms"]
print("bedrooms_in_most_rooms", bedrooms_in_most_rooms)

# What's the number of rooms in the house with the most bedrooms?
most_rooms = max(i["bedrooms"] for i in info_houses)
def bedroomskey(i):
    return i["bedrooms"]
rooms_in_most_bedrooms = max(info_houses, key= bedroomskey)["rooms"]
print("bedrooms_in_most_rooms", rooms_in_most_bedrooms)
# Out:
# {'longitude': -117.71, 'latitude': 34.15, 'age': 17, 'rooms': 7.66219723183391, 'bedrooms': 1.0250865051903115, 'value': 3491000}
# number of houses: 5779
# max value: 5497503
# most bedrooms: 1.9259259259259258
# bedrooms_in_most_rooms 1.75
# bedrooms_in_most_rooms 2.1481481481481484

# %%
# Test 04A
answers = [num_houses, max_value, most_bedrooms, bedrooms_in_most_rooms, rooms_in_most_bedrooms]

Tests.test("04A", answers)
# Out:
# 04A: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 04B:
#
# Which of the features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) is a better indicator for value of a house?
#
# We're going to use XY scatter plots to visualize house value as a function of each of these features, and see if any of them show strong correlation.
#
# Documentation for the plotting library is here:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# One thing to note is that the functions for plotting like to get lists of values and not lists of objects.
#
# Before we plot anything, let's define a function `list_from_key(objs, key)` that returns a list with all values of feature `key` for all of the objects in `objs`.

# %%
# Work on 04B here

# helper function to get lists of values from specific key
def list_from_key(objs, key):
  # TODO: implement the list_from_key functionality
  return []

# %%
# Test 04B
Tests.test("04B", list_from_key)

# %% [markdown]
# #### Exercise 04C:
#
# Now we can actually plot some values and start looking for correlations.
#
# Pick a feature and make a graph that shows house prices as a function of that feature.
#
# You can also write a for loop to plot graphs for all features.

# %%
# Work on 04C here

# TODO: get a list with all of the price values
prices = []

# TODO: get a list with all of the house ages (for example)
house_ages = []


# this is the command to plot a XY scatter plot from 2 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(house_ages, prices)
plt.xlabel("age")
plt.ylabel("value")
plt.show()

# %% [markdown]
# #### What are some features that correlate with price ?

# %% [markdown]
# Answer 04C here. Double-click to edit Markdown.

# %% [markdown]
# #### Foreshadowing:
#
# What if we use two features at a time?
#
# Is there a pair of features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) that correlates to house value?
#
# We could look at the relationship between `price`, `age` and `rooms`:

# %%
# get a list with all of the price values
prices = list_from_key(info_houses, "value")

# get a list with all of the values of one feature
feature_0_values = list_from_key(info_houses, "age")

# get a list with all of the values of another feature
feature_1_values = list_from_key(info_houses, "rooms")

# this is how we plot an XY scatter plot using 3 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(feature_0_values, feature_1_values, c=prices, alpha=0.3)
plt.xlabel("age")
plt.ylabel("rooms")
plt.show()

# %% [markdown]
# Or, we could write a little for loop to plot all possible pairs of features:

# %%
# to plot all feature pairs
# get list of all features
features = info_houses[0].keys()
prices = list_from_key(info_houses, "value")

# get all pairs of features
for idx_0, feature_0 in enumerate(features):
  x = list_from_key(info_houses, feature_0)
  for idx_1, feature_1 in enumerate(features):
    y = list_from_key(info_houses, feature_1)
    # skip repeated features
    if feature_0 != "value" and feature_1 != "value" and idx_1 > idx_0:
      plt.scatter(x, y, c=prices, alpha=0.3)
      plt.xlabel(feature_0)
      plt.ylabel(feature_1)
      plt.show()
